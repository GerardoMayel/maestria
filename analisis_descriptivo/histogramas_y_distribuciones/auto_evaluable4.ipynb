# %%
# !ls
# Out:
# auto_evaluable4.ipynb penguins.csv

# %%
# Importar las librerías necesarias
import pandas as pd

# Cargar el dataset manualmente
penguins_path = 'penguins.csv'  # Cambia <ruta_al_archivo> por el directorio donde guardaste el archivo
penguins = pd.read_csv(penguins_path)

# Mostrar las primeras filas del dataset
penguins.head(5)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
import pandas as pd

# Cargando el archivo penguins.csv
penguins_path = 'penguins.csv'
penguins = pd.read_csv(penguins_path)

# Imprimir información del dataset
print('Variables o columnas:')
print(penguins.columns)
print('\nTipos de datos:')
print(penguins.info())

# Mostrar las primeras filas del dataset
penguins.head()

# Respondiendo preguntas:
print("\nPreguntas:")
# Pregunta 1
print("Pregunta 1: La columna de ‘species’ es: a. Categórica")
# Pregunta 2
print("Pregunta 2: La columna de ‘island’ es: c. Categórica")
# Pregunta 3
print("Pregunta 3: La columna de ‘bill_length_mm’ es: c. Numérica")
# Pregunta 4
print("Pregunta 4: La columna de ‘bill_depth_mm’ es: c. Numérica")
# Pregunta 5
print("Pregunta 5: La columna de ‘flipper_length_mm’ es: a. Numérica")
# Pregunta 6
print("Pregunta 6: La columna de ‘body_mass_g’ es: a. Numérica")
# Pregunta 7
print("Pregunta 7: La columna de ‘sex’ es: a. Categórica")
# Pregunta 8
print("Pregunta 8: ¿Qué estadístico resume o aporta más información sobre la variable ‘bill_length_mm’?: b. Media")
# Pregunta 9
print("Pregunta 9: ¿Qué estadístico resume o aporta más información sobre la variable ‘species’?: b. Moda")
# Out:
# Variables o columnas:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')
#
# Tipos de datos:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB
# None
#
# Preguntas:
# Pregunta 1: La columna de ‘species’ es: a. Categórica
# Pregunta 2: La columna de ‘island’ es: c. Categórica
# Pregunta 3: La columna de ‘bill_length_mm’ es: c. Numérica
# ...
